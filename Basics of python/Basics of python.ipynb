# %% [markdown]
# # PYTHON PROGRAMMING ASSIGNMENT

# %% [markdown]
# ## Exercise 1: Prime Numbers
# #### Write a Python program that checks whether a given number is prime or not. A prime number is a natural number greater than 1 that has no positive divisors other than 1 and itself.

# %%
def is_prime(n):
    if n <= 1:
        return False
    for i in range(2, n):
        if n % i == 0:
            return False
    return True

num = int(input("Enter a number: "))
if is_prime(num):
    print(num, "is a prime number")
else:
    print(num, "is not a prime number")
# Out:
# 45 is not a prime number

# %% [markdown]
# ## Exercise 2: Product of Random Numbers
# #### Develop a Python program that generates two random numbers and asks the user to enter the product of these numbers. The program should then check if the user's answer is correct and display an appropriate message.

# %%
import random

# Generate two random numbers
num1 = random.randint(1, 100)
num2 = random.randint(1, 100)

# Calculate the product of the two numbers
product = num1 * num2

# Ask the user to enter the product
user_answer = int(input(f"What is the product of {num1} and {num2}? "))

# Check if the user's answer is correct
if user_answer == product:
    print(" Congratulations! Your answer is correct!")
else:
    print(f"Sorry, the correct answer is {product}.")
# Out:
# Sorry, the correct answer is 6806.

# %% [markdown]
# ## Exercise 3: Squares of Even/Odd Numbers
# #### Create a Python script that prints the squares of all even or odd numbers within the range of 100 to 200. Choose either even or odd numbers and document your choice in the code.

# %%
def even_square():
    for i in range(100,201):
        if i%2 == 0:
            print(i**2)
            
def odd_square():
    for i in range(100,201):
        if i%2 != 0:
            print(i**2)
            
user_choice=int(input("Enter 1 for Odd number squares or 2 for Even number squares"))
if user_choice ==1:
    odd_square()
elif user_choice==2:
    even_square()
else:
    print("invalid choice")
# Out:
# 10000
# 10404
# 10816
# 11236
# 11664
# 12100
# 12544
# 12996
# 13456
# 13924
# 14400
# 14884
# 15376
# 15876
# 16384
# 16900
# 17424
# 17956
# 18496
# 19044
# 19600
# 20164
# 20736
# 21316
# 21904
# 22500
# 23104
# 23716
# 24336
# 24964
# 25600
# 26244
# 26896
# 27556
# 28224
# 28900
# 29584
# 30276
# 30976
# 31684
# 32400
# 33124
# 33856
# 34596
# 35344
# 36100
# 36864
# 37636
# 38416
# 39204
# 40000

# %% [markdown]
# ## Exercise 4: Word counter
# #### write a program to count the number of words in a given text.

# %%
def count_words(input_text):
    words=input_text.split()
    counts={}
    for word in words:
        word = word.lower()
        if word in counts:
            counts[word] += 1
        else:
            counts[word] = 1
            
    return counts
            
input_text=input("enter your text") 
counts=count_words(input_text)
print(input_text)
print(counts)
# Out:
# this is a sample text. this will test  if this code is working correctly or not correctly.
# {'this': 3, 'is': 2, 'a': 1, 'sample': 1, 'text.': 1, 'will': 1, 'test': 1, 'if': 1, 'code': 1, 'working': 1, 'correctly': 1, 'or': 1, 'not': 1, 'correctly.': 1}

# %% [markdown]
# ## Exercise 5: Check for Palindrome
# #### Write a Python function called is_palindrome that takes a string as input and returns True if the string is a palindrome, and False otherwise. A palindrome is a word, phrase, number, or other sequence of characters that reads the same forward and backward, ignoring spaces, punctuation, and capitalization.

# %%
def is_palindrome(s):
    s = s.replace(" ", "").lower()  # remove spaces and convert to lowercase
    return s == s[::-1]  # check if the string is the same when reversed

s=input("enter the word")
print("Input word:",s)
print(is_palindrome(s))
print("reverse of the word:",s[::-1])
# Out:
# Input word: hello
# False
# reverse of the word: olleh

# %% [markdown]
# ## Submitted By:
# # Soheb Khan
